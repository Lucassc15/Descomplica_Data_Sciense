# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucassc15/Descomplica_Data_Sciense/blob/main/Aula%20de%20regress%C3%A3o%20linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
# variável preditora
X = np.array([ 220, 220, 220, 220, 220, 225, 225, 225, 225, 225, 230, 230, 230, 230, 230, 235, 235, 235, 235, 235 ])
# variável alvo
y = np.array([ 137, 137, 137, 136, 135, 135, 133, 132, 133, 133, 128, 124, 126, 129, 126, 122, 122, 122, 119, 122 ])

# %%
# é necessário adicionar uma constante a matriz X
X_sm = sm.add_constant(X)

# %%
# OLS vem de Ordinary Least Squares e o método fit irá treinar o modelo
results = sm.OLS(y, X_sm).fit()

# %%
# mostrando as estatísticas do modelo
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.942
# Model:                            OLS   Adj. R-squared:                  0.939
# Method:                 Least Squares   F-statistic:                     291.1
# Date:                Thu, 20 Nov 2025   Prob (F-statistic):           1.47e-12
# Time:                        10:41:44   Log-Likelihood:                -35.596
# No. Observations:                  20   AIC:                             75.19
# Df Residuals:                      18   BIC:                             77.18
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        364.1800     13.765     26.457      0.000     335.261     393.099
# ...
